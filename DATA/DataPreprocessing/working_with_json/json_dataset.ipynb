# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json("countries.json")

# %%
df.head(10)
# Out:
#                                            countries
# 0  {'name': 'Afghanistan', 'code': 'AF', 'capital...
# 1  {'name': 'Albania', 'code': 'AL', 'capital': '...
# 2  {'name': 'Algeria', 'code': 'DZ', 'capital': '...
# 3  {'name': 'Argentina', 'code': 'AR', 'capital':...
# 4  {'name': 'Australia', 'code': 'AU', 'capital':...
# 5  {'name': 'Austria', 'code': 'AT', 'capital': '...
# 6  {'name': 'Belgium', 'code': 'BE', 'capital': '...
# 7  {'name': 'Brazil', 'code': 'BR', 'capital': 'B...
# 8  {'name': 'Canada', 'code': 'CA', 'capital': 'O...
# 9  {'name': 'Chile', 'code': 'CL', 'capital': 'Sa...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   countries  51 non-null     object
# dtypes: object(1)
# memory usage: 540.0+ bytes

# %%
df.isnull().mean()*100
# Out:
# countries    0.0
# dtype: float64

# %%
new_df = df.head(10)

# %%
new_df.shape
# Out:
# (10, 1)

# %%
df.isnull()
# Out:
#     countries
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44      False
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False
# 50      False

# %%
df.drop_duplicates()
# Out:
#                                             countries
# 0   {'name': 'Afghanistan', 'code': 'AF', 'capital...
# 1   {'name': 'Albania', 'code': 'AL', 'capital': '...
# 2   {'name': 'Algeria', 'code': 'DZ', 'capital': '...
# 3   {'name': 'Argentina', 'code': 'AR', 'capital':...
# 4   {'name': 'Australia', 'code': 'AU', 'capital':...
# 5   {'name': 'Austria', 'code': 'AT', 'capital': '...
# 6   {'name': 'Belgium', 'code': 'BE', 'capital': '...
# 7   {'name': 'Brazil', 'code': 'BR', 'capital': 'B...
# 8   {'name': 'Canada', 'code': 'CA', 'capital': 'O...
# 9   {'name': 'Chile', 'code': 'CL', 'capital': 'Sa...
# 10  {'name': 'China', 'code': 'CN', 'capital': 'Be...
# 11  {'name': 'Colombia', 'code': 'CO', 'capital': ...
# 12  {'name': 'Czech Republic', 'code': 'CZ', 'capi...
# 13  {'name': 'Denmark', 'code': 'DK', 'capital': '...
# 14  {'name': 'Egypt', 'code': 'EG', 'capital': 'Ca...
# 15  {'name': 'Finland', 'code': 'FI', 'capital': '...
# ...

# %%
df.
